# %%
# To import
import pandas as pd
path="https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"
df=pd.read_csv(path,header=None)
df.columns=["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]

# to replace the null values
import numpy as np
df.replace("?",np.nan, inplace=True)

#to check the colums having null values

null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().count()

#to replace value by mean

norloss=df["normalized-losses"].astype("float").mean(axis=0)
df["normalized-losses"].replace(np.nan,norloss,inplace=True)

bor=df["bore"].astype("float").mean(axis=0)
df["bore"].replace(np.nan,bor,inplace=True)

strk=df["stroke"].astype("float").mean(axis=0)
df["stroke"].replace(np.nan,strk,inplace=True)

horpow=df["horsepower"].astype("float").mean(axis=0)
df["horsepower"].replace(np.nan,horpow,inplace=True)

rpm=df["peak-rpm"].astype("float").mean(axis=0)
df["peak-rpm"].replace(np.nan,rpm,inplace=True)

#to replace the value with frequence

nd=df["num-of-doors"].value_counts().idxmax()
df["num-of-doors"].replace(np.nan,nd,inplace=True)

# to drop the values

df.dropna(subset=["price"],axis=0, inplace=True)

# to change the data type 

df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df["normalized-losses"] = df["normalized-losses"].astype("int")
df[["price","peak-rpm"]] = df[["price","peak-rpm"]].astype("float")

# to standardise the data 

df["city-L/100km"]=235/df["city-mpg"]
df["highway-L/100km"]=235/df["highway-mpg"]

# to normalise the data

df["length"]=df["length"]/df["length"].max()
df["width"]=df["width"]/df["width"].max()
df["height"]=df["height"]/df["height"].max()

# %% [markdown]
# # To check the data types

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# highway-L/100km      float64
# dtype: object

# %%
# to describe the data
df.describe(include="all")
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           205        205          205             205  205.000000  ...
# unique            3          5            3               2         NaN  ...
# top            four      sedan          fwd           front         NaN  ...
# freq            114         96          120             202         NaN  ...
# mean            NaN        NaN          NaN             NaN   98.756585  ...
# std             NaN        NaN          NaN             NaN    6.021776  ...
# min             NaN        NaN          NaN             NaN   86.600000  ...
# 25%             NaN        NaN          NaN             NaN   94.500000  ...
# 50%             NaN        NaN          NaN             NaN   97.000000  ...
# 75%             NaN        NaN          NaN             NaN  102.400000  ...
# max             NaN        NaN          NaN             NaN  120.900000  ...
#
#         engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# count    205.000000          205   205     205        205.000000        205
# unique          NaN            8    39      37               NaN         60
# top             NaN         mpfi  3.62    3.40               NaN         68
# freq            NaN           94    23      20               NaN         19
# mean     126.907317          NaN   NaN     NaN         10.142537        NaN
# std       41.642693          NaN   NaN     NaN          3.972040        NaN
# min       61.000000          NaN   NaN     NaN          7.000000        NaN
# 25%       97.000000          NaN   NaN     NaN          8.600000        NaN
# 50%      120.000000          NaN   NaN     NaN          9.000000        NaN
# 75%      141.000000          NaN   NaN     NaN          9.400000        NaN
# max      326.000000          NaN   NaN     NaN         23.000000        NaN
#
#         peak-rpm    city-mpg highway-mpg price
# count        205  205.000000  205.000000   205
# unique        24         NaN         NaN   187
# top         5500         NaN         NaN     ?
# freq          37         NaN         NaN     4
# mean         NaN   25.219512   30.751220   NaN
# std          NaN    6.542142    6.886443   NaN
# min          NaN   13.000000   16.000000   NaN
# 25%          NaN   19.000000   25.000000   NaN
# 50%          NaN   24.000000   30.000000   NaN
# 75%          NaN   30.000000   34.000000   NaN
# max          NaN   49.000000   54.000000   NaN
#
# [11 rows x 26 columns]

# %%
import numpy as np
df.replace("?",np.nan, inplace=True)
df.head(5)
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          3                122  alfa-romero          two  convertible
# 2          1                122  alfa-romero          two    hatchback
# 3          2                164         audi         four        sedan
# 4          2                164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  peak-rpm  \
# 0          rwd           front        88.6  0.811148  0.890278  ...    5000.0
# 1          rwd           front        88.6  0.811148  0.890278  ...    5000.0
# 2          rwd           front        94.5  0.822681  0.909722  ...    5000.0
# 3          fwd           front        99.8  0.848630  0.919444  ...    5500.0
# 4          4wd           front        99.4  0.848630  0.922222  ...    5500.0
#
#    city-mpg highway-mpg    price  city-L/100km highway-L/100km  diesel  gas  \
# 0        21          27  13495.0     11.190476        8.703704       0    1
# 1        21          27  16500.0     11.190476        8.703704       0    1
# 2        19          26  16500.0     12.368421        9.038462       0    1
# 3        24          30  13950.0      9.791667        7.833333       0    1
# 4        18          22  17450.0     13.055556       10.681818       0    1
#
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0
#
# [5 rows x 30 columns]

# %%
null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().count()
# Out:
# Series([], dtype: int64)

# %%
norloss=df["normalized-losses"].astype("float").mean(axis=0)
print(norloss)
df["normalized-losses"].replace(np.nan,norloss,inplace=True)

bor=df["bore"].astype("float").mean(axis=0)
print(bor)
df["bore"].replace(np.nan,bor,inplace=True)

strk=df["stroke"].astype("float").mean(axis=0)
print(strk)
df["stroke"].replace(np.nan,strk,inplace=True)

horpow=df["horsepower"].astype("float").mean(axis=0)
print(horpow)
df["horsepower"].replace(np.nan,horpow,inplace=True)

rpm=df["peak-rpm"].astype("float").mean(axis=0)
print(rpm)
df["peak-rpm"].replace(np.nan,rpm,inplace=True)
# Out:
# 122.0
# 3.33069156704042
# 3.2568740872750674
# 103.40553390682057
# 5117.665367742568

# %%
nd=df["num-of-doors"].value_counts().idxmax()
df["num-of-doors"].replace(np.nan,nd,inplace=True)
df.dropna(subset=["price"],axis=0, inplace=True)

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df["normalized-losses"] = df["normalized-losses"].astype("int")
df[["price"]] = df[["price"]].astype("float64")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")
df[["engine-size"]] = df[["engine-size"]].astype("float64")

# %%
df["city-L/100km"]=235/df["city-mpg"]
df["highway-L/100km"]=235/df["highway-mpg"]

# %%
df["length"]=df["length"]/df["length"].max()
df["width"]=df["width"]/df["width"].max()
df["height"]=df["height"]/df["height"].max()

# %%
df["horsepower"]=df["horsepower"].astype("int",copy=True)

import matplotlib.pyplot as plt



bins = np.linspace(min(df["horsepower"]),max(df["horsepower"]),4)
grp_name=["low","medium","high"]
df["hrpbin"]=pd.cut(df["horsepower"],bins,labels=grp_name,include_lowest=True)
df[["horsepower","hrpbin"]].head(10)
df["hrpbin"].value_counts()

plt.bar(grp_name, df["hrpbin"].value_counts())
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horse power bins 2")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-39-ac2fdbf69608> in <module>
#       1 df["horsepower"]=df["horsepower"].astype("int",copy=True)
#       2
# ----> 3 import matplotlib.pyplot as plt
#       4
#       5
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\pyplot.py in <module>
#      38 from matplotlib import docstring
#      39 from matplotlib.backend_bases import FigureCanvasBase
# ---> 40 from matplotlib.figure import Figure, figaspect
#      41 from matplotlib.gridspec import GridSpec
#      42 from matplotlib import rcParams, rcParamsDefault, get_backend, rcParamsOrig
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\figure.py in <module>
#      18
#      19 from matplotlib import rcParams
# ---> 20 from matplotlib import backends, docstring, projections
#      21 from matplotlib import __version__ as _mpl_version
#      22 from matplotlib import get_backend
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\projections\__init__.py in <module>
# ----> 1 from .. import axes, cbook
#       2 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#       3 from .polar import PolarAxes
#       4
#       5
#
# ImportError: cannot import name 'axes' from 'matplotlib' (c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\__init__.py)

# %%
plt.pyplot.hist(df["horsepower"])

plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horse power bins 1")

plt.pyplot.hist(df["horsepower"],bins=3)

plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horse power bins 3")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-fcd5c6e74173> in <module>
# ----> 1 plt.pyplot.hist(df["horsepower"])
#       2
#       3 plt.pyplot.xlabel("horsepower")
#       4 plt.pyplot.ylabel("count")
#       5 plt.pyplot.title("horse power bins 1")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'

# %%
dummyvar= pd.get_dummies(df["fuel-type"])
dummyvar.rename(columns={'fuel-type':'gas','fuel-type':'diesel'},inplace=True)
df=pd.concat([df, dummyvar],axis=1)
df.drop("fuel-type", axis = 1, inplace=True)

# %%
import pandas as pd
dum=pd.get_dummies(df["aspiration"])
dum.rename(columns={'aspiration-std':'std','aspiration-turbo':'turbo'},inplace=True)
df=pd.concat([df,dum],axis=1)
df.drop("aspiration",axis=1,inplace=True)

# %%
df["peak-rpm"].dtypes
# Out:
# dtype('float64')

# %%
df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566903
# stroke            -0.055390  1.000000           0.187871    0.098128
# compression-ratio  0.001263  0.187871           1.000000   -0.214489
# horsepower         0.566903  0.098128          -0.214489    1.000000

# %%
import seaborn as sns

df[['highway-mpg','price']].corr()

sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-40-277e4b107cb8> in <module>
# ----> 1 import seaborn as sns
#       2
#       3 df[['highway-mpg','price']].corr()
#       4
#       5 sns.regplot(x="highway-mpg", y="price", data=df)
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\__init__.py in <module>
#       4
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\rcmod.py in <module>
#       4 import matplotlib as mpl
#       5 import warnings
# ----> 6 from . import palettes, _orig_rc_params
#       7
#       8
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\palettes.py in <module>
#       8 from .external import husl
#       9
# ---> 10 from .utils import desaturate, set_hls_values, get_color_cycle
#      11 from .colors import xkcd_rgb, crayons
#      12
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\utils.py in <module>
#       9 import matplotlib as mpl
#      10 import matplotlib.colors as mplcol
# ---> 11 import matplotlib.pyplot as plt
#      12
#      13 from urllib.request import urlopen, urlretrieve
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\pyplot.py in <module>
#      38 from matplotlib import docstring
#      39 from matplotlib.backend_bases import FigureCanvasBase
# ---> 40 from matplotlib.figure import Figure, figaspect
#      41 from matplotlib.gridspec import GridSpec
#      42 from matplotlib import rcParams, rcParamsDefault, get_backend, rcParamsOrig
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\figure.py in <module>
#      18
#      19 from matplotlib import rcParams
# ---> 20 from matplotlib import backends, docstring, projections
#      21 from matplotlib import __version__ as _mpl_version
#      22 from matplotlib import get_backend
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\projections\__init__.py in <module>
# ----> 1 from .. import axes, cbook
#       2 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#       3 from .polar import PolarAxes
#       4
#       5
#
# ImportError: cannot import name 'axes' from 'matplotlib' (c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\__init__.py)

# %%
df["horsepower"]=df["horsepower"].astype("int",copy=True)

import matplotlib as plt
from matplotlib import pyplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-44-a6edfb72cb4b> in <module>
#       2
#       3 import matplotlib as plt
# ----> 4 from matplotlib import pyplot
#       5
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\pyplot.py in <module>
#      38 from matplotlib import docstring
#      39 from matplotlib.backend_bases import FigureCanvasBase
# ---> 40 from matplotlib.figure import Figure, figaspect
#      41 from matplotlib.gridspec import GridSpec
#      42 from matplotlib import rcParams, rcParamsDefault, get_backend, rcParamsOrig
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\figure.py in <module>
#      18
#      19 from matplotlib import rcParams
# ---> 20 from matplotlib import backends, docstring, projections
#      21 from matplotlib import __version__ as _mpl_version
#      22 from matplotlib import get_backend
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\projections\__init__.py in <module>
# ----> 1 from .. import axes, cbook
#       2 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#       3 from .polar import PolarAxes
#       4
#       5
#
# ImportError: cannot import name 'axes' from 'matplotlib' (c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\matplotlib\__init__.py)
